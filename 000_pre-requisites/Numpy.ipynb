# %% [markdown]
# # Numpy
#
# ## Create numpy array
#
# ### 1) Using a list

# %%
import numpy as np
list_ = [1,2,3]
arr = np.array(list_)
arr
# Out:
# array([1, 2, 3])

# %% [markdown]
# #### 2D array

# %%
list2 = [[1,2,3],[4,5,6]]
arr2 = np.array(list2)
arr2
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
