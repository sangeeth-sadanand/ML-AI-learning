# %% [markdown]
# # Data encoding

# %%
import pandas as pd
import seaborn as sns

# Load Titanic dataset
df = sns.load_dataset('titanic')

# Select relevant categorical columns
df = df[['sex', 'embarked', 'class', 'who', 'survived']]
df.dropna(inplace=True)

# %% [markdown]
# ## One-Hot Encoding

# %%
# Using pandas
df_ohe = pd.get_dummies(df, columns=['embarked'], prefix='embarked', drop_first=True)
df_ohe
# Out:
#         sex   class    who  survived  embarked_Q  embarked_S
# 0      male   Third    man         0       False        True
# 1    female   First  woman         1       False       False
# 2    female   Third  woman         1       False        True
# 3    female   First  woman         1       False        True
# 4      male   Third    man         0       False        True
# ..      ...     ...    ...       ...         ...         ...
# 886    male  Second    man         0       False        True
# 887  female   First  woman         1       False        True
# 888  female   Third  woman         0       False        True
# 889    male   First    man         1       False       False
# 890    male   Third    man         0        True       False
#
# [889 rows x 6 columns]

# %%
# Using Sklearn
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(sparse_output=False, drop="first")
encoded = ohe.fit_transform(df[['embarked']])
df_ohe_sklearn = pd.DataFrame(encoded, columns=ohe.get_feature_names_out(['embarked']))
df_ohe_sklearn
# Out:
#      embarked_Q  embarked_S
# 0           0.0         1.0
# 1           0.0         0.0
# 2           0.0         1.0
# 3           0.0         1.0
# 4           0.0         1.0
# ..          ...         ...
# 884         0.0         1.0
# 885         0.0         1.0
# 886         0.0         1.0
# 887         0.0         0.0
# 888         1.0         0.0
#
# [889 rows x 2 columns]

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['sex_le'] = le.fit_transform(df['sex'])  # male=1, female=0
df
# Out:
#         sex embarked   class    who  survived  sex_le
# 0      male        S   Third    man         0       1
# 1    female        C   First  woman         1       0
# 2    female        S   Third  woman         1       0
# 3    female        S   First  woman         1       0
# 4      male        S   Third    man         0       1
# ..      ...      ...     ...    ...       ...     ...
# 886    male        S  Second    man         0       1
# 887  female        S   First  woman         1       0
# 888  female        S   Third  woman         0       0
# 889    male        C   First    man         1       1
# 890    male        Q   Third    man         0       1
#
# [889 rows x 6 columns]

# %%
le = LabelEncoder()
df['embarked_le'] = le.fit_transform(df['embarked'])  # male=1, female=0
df
# Out:
#         sex embarked   class    who  survived  sex_le  embarked_le
# 0      male        S   Third    man         0       1            2
# 1    female        C   First  woman         1       0            0
# 2    female        S   Third  woman         1       0            2
# 3    female        S   First  woman         1       0            2
# 4      male        S   Third    man         0       1            2
# ..      ...      ...     ...    ...       ...     ...          ...
# 886    male        S  Second    man         0       1            2
# 887  female        S   First  woman         1       0            2
# 888  female        S   Third  woman         0       0            2
# 889    male        C   First    man         1       1            0
# 890    male        Q   Third    man         0       1            1
#
# [889 rows x 7 columns]

# %% [markdown]
# ## Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# Define order: First < Second < Third
ord_enc = OrdinalEncoder(categories=[['First', 'Second', 'Third']])
df['class_ord'] = ord_enc.fit_transform(df[['class']])
df
# Out:
#         sex embarked   class    who  survived  sex_le  embarked_le  class_ord
# 0      male        S   Third    man         0       1            2        2.0
# 1    female        C   First  woman         1       0            0        0.0
# 2    female        S   Third  woman         1       0            2        2.0
# 3    female        S   First  woman         1       0            2        0.0
# 4      male        S   Third    man         0       1            2        2.0
# ..      ...      ...     ...    ...       ...     ...          ...        ...
# 886    male        S  Second    man         0       1            2        1.0
# 887  female        S   First  woman         1       0            2        0.0
# 888  female        S   Third  woman         0       0            2        2.0
# 889    male        C   First    man         1       1            0        0.0
# 890    male        Q   Third    man         0       1            1        2.0
#
# [889 rows x 8 columns]

# %% [markdown]
# ## Target Encoding

# %%
target_map = df.groupby('who')['survived'].mean()
df['who_target'] = df['who'].map(target_map)
df
# Out:
#         sex embarked   class    who  survived  sex_le  embarked_le  class_ord  \
# 0      male        S   Third    man         0       1            2        2.0
# 1    female        C   First  woman         1       0            0        0.0
# 2    female        S   Third  woman         1       0            2        2.0
# 3    female        S   First  woman         1       0            2        0.0
# 4      male        S   Third    man         0       1            2        2.0
# ..      ...      ...     ...    ...       ...     ...          ...        ...
# 886    male        S  Second    man         0       1            2        1.0
# 887  female        S   First  woman         1       0            2        0.0
# 888  female        S   Third  woman         0       0            2        2.0
# 889    male        C   First    man         1       1            0        0.0
# 890    male        Q   Third    man         0       1            1        2.0
#
#      who_target
# 0      0.163873
# 1      0.754647
# 2      0.754647
# 3      0.754647
# 4      0.163873
# ..          ...
# 886    0.163873
# 887    0.754647
# 888    0.754647
# 889    0.163873
# 890    0.163873
#
# [889 rows x 9 columns]

# %% [markdown]
# ## Frequency Encoding

# %%
freq_map = df['embarked'].value_counts()
df['embarked_freq'] = df['embarked'].map(freq_map)
df
# Out:
#         sex embarked   class    who  survived  sex_le  embarked_le  class_ord  \
# 0      male        S   Third    man         0       1            2        2.0
# 1    female        C   First  woman         1       0            0        0.0
# 2    female        S   Third  woman         1       0            2        2.0
# 3    female        S   First  woman         1       0            2        0.0
# 4      male        S   Third    man         0       1            2        2.0
# ..      ...      ...     ...    ...       ...     ...          ...        ...
# 886    male        S  Second    man         0       1            2        1.0
# 887  female        S   First  woman         1       0            2        0.0
# 888  female        S   Third  woman         0       0            2        2.0
# 889    male        C   First    man         1       1            0        0.0
# 890    male        Q   Third    man         0       1            1        2.0
#
#      who_target  embarked_freq
# 0      0.163873            644
# 1      0.754647            168
# 2      0.754647            644
# 3      0.754647            644
# 4      0.163873            644
# ..          ...            ...
# 886    0.163873            644
# 887    0.754647            644
# 888    0.754647            644
# 889    0.163873            168
# 890    0.163873             77
#
# [889 rows x 10 columns]

# %% [markdown]
# ## Binary Encoding

# %%
# !pip install category_encoders

import category_encoders as ce

be = ce.BinaryEncoder()
df_be = be.fit_transform(df['who'])
df_be
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (2.1.3)
# Requirement already satisfied: pandas>=1.0.5 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (2.2.3)
# Requirement already satisfied: patsy>=0.5.1 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (1.0.1)
# Requirement already satisfied: scikit-learn>=1.6.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (1.6.1)
# Requirement already satisfied: scipy>=1.0.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (1.15.3)
# Requirement already satisfied: statsmodels>=0.9.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from category_encoders) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sans/anaconda3/lib/python3.13/site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sans/anaconda3/lib/python3.13/site-packages (from pandas>=1.0.5->category_encoders) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sans/anaconda3/lib/python3.13/site-packages (from pandas>=1.0.5->category_encoders) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/sans/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.6.0->category_encoders) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.6.0->category_encoders) (3.5.0)
# Requirement already satisfied: packaging>=21.3 in /home/sans/anaconda3/lib/python3.13/site-packages (from statsmodels>=0.9.0->category_encoders) (24.2)
# Downloading category_encoders-2.8.1-py3-none-any.whl (85 kB)
# Installing collected packages: category_encoders
# Successfully installed category_encoders-2.8.1
#      who_0  who_1
# 0        0      1
# 1        1      0
# 2        1      0
# 3        1      0
# 4        0      1
# ..     ...    ...
# 886      0      1
# 887      1      0
# 888      1      0
# 889      0      1
# 890      0      1
#
# [889 rows x 2 columns]
