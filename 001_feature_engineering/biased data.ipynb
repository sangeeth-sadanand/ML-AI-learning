# %% [markdown]
# # Handling Biased data

# %%
import seaborn as sns
import pandas as pd
from sklearn.utils import resample

# Load Titanic dataset
df = sns.load_dataset('titanic')

# Drop rows with missing 'age' or 'embarked'
df = df.dropna(subset=['age', 'embarked'])

# Select features and target
X = df[['pclass', 'sex', 'age', 'embarked']]
y = df['survived']

X_encoded = pd.get_dummies(X, drop_first=True)


# Combine features and target
df_combined = pd.concat([X_encoded, y], axis=1)

# %%
X_encoded
# Out:
#      pclass   age  sex_male  embarked_Q  embarked_S
# 0         3  22.0      True       False        True
# 1         1  38.0     False       False       False
# 2         3  26.0     False       False        True
# 3         1  35.0     False       False        True
# 4         3  35.0      True       False        True
# ..      ...   ...       ...         ...         ...
# 885       3  39.0     False        True       False
# 886       2  27.0      True       False        True
# 887       1  19.0     False       False        True
# 889       1  26.0      True       False       False
# 890       3  32.0      True        True       False
#
# [712 rows x 5 columns]

# %%
# Separate majority and minority classes
df_majority = df_combined[df_combined['survived'] == 0]
df_minority = df_combined[df_combined['survived'] == 1]

# %%
df_minority.count()
# Out:
# pclass        288
# age           288
# sex_male      288
# embarked_Q    288
# embarked_S    288
# survived      288
# dtype: int64

# %%
df_majority.count()
# Out:
# pclass        424
# age           424
# sex_male      424
# embarked_Q    424
# embarked_S    424
# survived      424
# dtype: int64

# %%
# Upsample minority class
df_minority_upsampled = resample(df_minority,
                                 replace=True,
                                 n_samples=len(df_majority),
                                 random_state=42)

df_minority_upsampled.count()
# Out:
# pclass        424
# age           424
# sex_male      424
# embarked_Q    424
# embarked_S    424
# survived      424
# dtype: int64

# %%
# Combine back
df_balanced = pd.concat([df_majority, df_minority_upsampled])
df_balanced.count()
# Out:
# pclass        848
# age           848
# sex_male      848
# embarked_Q    848
# embarked_S    848
# survived      848
# dtype: int64

# %%
# Upsample minority class
df_majority_downsampled = resample(df_majority,
                                 replace=True,
                                 n_samples=len(df_minority),
                                 random_state=42)

df_majority_downsampled.count()
# Out:
# pclass        288
# age           288
# sex_male      288
# embarked_Q    288
# embarked_S    288
# survived      288
# dtype: int64

# %%
df_balanced = pd.concat([df_majority_downsampled, df_minority])
df_balanced.count()
# Out:
# pclass        576
# age           576
# sex_male      576
# embarked_Q    576
# embarked_S    576
# survived      576
# dtype: int64

# %% [markdown]
# ## SMOTE

# %%
## SMOTE upsampling
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /home/sans/anaconda3/lib/python3.13/site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (2.1.3)
# Requirement already satisfied: scipy<2,>=1.10.1 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/sans/anaconda3/lib/python3.13/site-packages (from imbalanced-learn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# Initialize SMOTE
smote = SMOTE(random_state=42)

X_resampled, y_resampled = smote.fit_resample(X_encoded, y)

from collections import Counter
print(Counter(y_resampled))
# Out:
# Counter({0: 424, 1: 424})

# %% [markdown]
# ## ADASYN

# %%
from imblearn.over_sampling import ADASYN

# Initialize ADASYN
adasyn = ADASYN(random_state=42)

# Fit and resample
X_resampled, y_resampled = adasyn.fit_resample(X_encoded, y)

from collections import Counter
print(Counter(y_resampled))
# Out:
# Counter({0: 424, 1: 384})
